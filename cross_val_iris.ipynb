# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
df= pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.dropna(inplace = True)

# %%
df.drop_duplicates(inplace= True)

# %%
df.shape
# Out:
# (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
X = df.drop(columns = 'Outcome')
Y = df['Outcome']

# %%
xtrain, xtest, ytrain,ytest = train_test_split(X, Y, test_size= 0.2, stratify=Y , random_state= 2)
print(xtrain.shape, xtest.shape)
# Out:
# (614, 8) (154, 8)

# %% [markdown]
# Multiple models that can train the data in all of these models

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
# create the list of multiple models 
models = [DecisionTreeClassifier(), LogisticRegression(),  KNeighborsClassifier(n_neighbors=5), SVC(kernel = 'linear'),RandomForestClassifier()]

# %% [markdown]
# compare & check the accuracy score between all models

# %%
for i in models:
    i.fit(xtrain, ytrain)
    y_pred = i.predict(xtest)
    accuracy = accuracy_score(ytest, y_pred)
    print('accuracy score of the all models', i,'=', accuracy)
# Out:
# accuracy score of the all models DecisionTreeClassifier() = 0.6948051948051948
# accuracy score of the all models LogisticRegression() = 0.7532467532467533
# accuracy score of the all models KNeighborsClassifier() = 0.7272727272727273
# c:\Users\AL-HAMD\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# accuracy score of the all models SVC(kernel='linear') = 0.7727272727272727
# accuracy score of the all models RandomForestClassifier() = 0.7272727272727273

# %% [markdown]
# compare & Check the Cross Validation Score between all models

# %%
for i in models:
    cross_validataion_score = cross_val_score(i, X, Y, cv=5)
    accuracy_of_cross_val = sum(cross_validataion_score)/len(cross_validataion_score)
    print('Cross Validation score of all the models', i, '=', accuracy_of_cross_val)
# Out:
# Cross Validation score of all the models DecisionTreeClassifier() = 0.7019607843137254
# c:\Users\AL-HAMD\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AL-HAMD\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
# ...

# %% [markdown]
# Create a models HyperParameter

# %%
models_hyperparameter = {
    'DecisionTreeClassifier' : {
        'criterion': ['gini', 'entropy', 'log_loss'], 
        'max_depth' : [2,3,4]
        },
    'LogisticRegression' : {
        'C' : [10,100,1000]
        },
    'KNeighborsClassifier' : {
            'n_neighbors' : [1,5,10]
        },
    'SVC' : {
            'kernel' : ['linear', 'poly','rbf', 'sigmoid']
            },
    ' RandomForestClassifier' : {
            'n_estimators' : [50,100,150,300]
        }

}

# %%
models_hyperparameter
# Out:
# {'DecisionTreeClassifier': {'criterion': ['gini', 'entropy', 'log_loss'],
#   'max_depth': [2, 3, 4]},
#  'LogisticRegression': {'C': [10, 100, 1000]},
#  'KNeighborsClassifier': {'n_neighbors': [1, 5, 10]},
#  'SVC': {'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#  ' RandomForestClassifier': {'n_estimators': [50, 100, 150, 300]}}

# %%
model_keys = models_hyperparameter.keys()

# %%
models_hyperparameter.values()
# Out:
# dict_values([{'criterion': ['gini', 'entropy', 'log_loss'], 'max_depth': [2, 3, 4]}, {'C': [10, 100, 1000]}, {'n_neighbors': [1, 5, 10]}, {'kernel': ['linear', 'poly', 'rbf', 'sigmoid']}, {'n_estimators': [50, 100, 150, 300]}])

# %%
list(models_hyperparameter.keys())
# Out:
# ['DecisionTreeClassifier',
#  'LogisticRegression',
#  'KNeighborsClassifier',
#  'SVC',
#  ' RandomForestClassifier']

# %%
list(models_hyperparameter.items())
# Out:
# [('DecisionTreeClassifier',
#   {'criterion': ['gini', 'entropy', 'log_loss'], 'max_depth': [2, 3, 4]}),
#  ('LogisticRegression', {'C': [10, 100, 1000]}),
#  ('KNeighborsClassifier', {'n_neighbors': [1, 5, 10]}),
#  ('SVC', {'kernel': ['linear', 'poly', 'rbf', 'sigmoid']}),
#  (' RandomForestClassifier', {'n_estimators': [50, 100, 150, 300]})]

# %%
type(models_hyperparameter)
# Out:
# dict

# %% [markdown]
# Compare the models between different hyperparameters by using GridSearchCV

# %%
model = [DecisionTreeClassifier(), RandomForestClassifier()]

# %%
dtc = DecisionTreeClassifier()
criterion = ['gini', 'entropy']
max_depth = [2,3,4, None]
max_features = ['auto','sqrt', None]
max_leaf_nodes = [3,4,None]
random_state = [2,42,36]

DecisionTree_hyperparameter_para_grid = {
            'criterion' : criterion,
            'max_depth' : max_depth,
            'max_features' : max_features,
            'max_leaf_nodes' : max_leaf_nodes,
            'random_state' : random_state
}

# %%
rfc = RandomForestClassifier()
n_estimators = [50,100,150,300]
criterion = ['gini', 'entropy']
max_depth = [2,3, None]
max_features = ['auto','sqrt', None]
max_leaf_nodes = [3,4,5,None]
random_state = [2,5,40, None]

RandomForest_hyperparameter_para_grid = {
            'n_estimators' : n_estimators,
            'criterion' : criterion,
            'max_depth' : max_depth,
            'max_features' : max_features,
            'max_leaf_nodes' : max_leaf_nodes,
            'random_state' : random_state
}

# %%
hyperparameter_list = {
    
        'DecisionTree_hyperparameter_para_grid' : {
            'criterion' : criterion,
            'max_depth' : max_depth,
            'max_features' : max_features,
            'max_leaf_nodes' : max_leaf_nodes,
            'random_state' : random_state
        },

        'RandomForest_hyperparameter_para_grid' : {
            'n_estimators' : n_estimators,
            'criterion' : criterion,
            'max_depth' : max_depth,
            'max_features' : max_features,
            'max_leaf_nodes' : max_leaf_nodes,
            'random_state' : random_state
}
    
}


type(hyperparameter_list)
model_key = hyperparameter_list.keys()
model_key
from sklearn.model_selection import GridSearchCV
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[286], line 24
#       1 hyperparameter_list = {
#       2
#       3         'DecisionTree_hyperparameter_para_grid' : {
#    (...)
#      19
#      20 }
#      23 type(hyperparameter_list)
# ---> 24 model_key = hyperparameter_list.keys([0])
#      25 model_key
#      26 from sklearn.model_selection import GridSearchCV
#
# TypeError: dict.keys() takes no arguments (1 given)

# %%
for i in range(0,2):
    model_key = hyperparameter_list.keys()
    model_key[i]  
    i = i+1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[289], line 3
#       1 for i in range(0,2):
#       2     model_key = hyperparameter_list.keys()
# ----> 3     model_key.iloc[i]
#       4     i = i+1
#
# AttributeError: 'dict_keys' object has no attribute 'iloc'

# %%
def model_selection(model_list, hyperparameter_dictionary):
    result= []
    i=0
    for j in model_list:
        key = model_key[i]
        param = hyperparameter_dictionary(j)
        i = i+1

    gscv = GridSearchCV(estimator= key,  param_grid= param, cv=5, n_jobs= -1)
    gscv.fit(xtrain,ytrain)

# %%
model_selection(model , hyperparameter_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[284], line 1
# ----> 1 model_selection(model , hyperparameter_list)
#
# Cell In[283], line 5, in model_selection(model_list, hyperparameter_dictionary)
#       3 i=0
#       4 for j in model_list:
# ----> 5     key = model_key[i]
#       6     param = hyperparameter_dictionary(j)
#       7     i = i+1
#
# TypeError: 'dict_keys' object is not subscriptable

# %%
from sklearn.model_selection import GridSearchCV
gscv = GridSearchCV(estimator= dtc,  param_grid= DecisionTree_hyperparameter_para_grid, cv=5, n_jobs= -1)
gscv.fit(xtrain, ytrain)
# Out:
# c:\Users\AL-HAMD\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:542: FitFailedWarning:
# 360 fits failed out of a total of 1080.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 266 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\AL-HAMD\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 890, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\AL-HAMD\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1344, in wrapper
#     estimator._validate_params()
# ...

# %%
gscv.best_score_
# Out:
# 0.7686925229908037

# %%
gscv.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 2,
#  'max_features': None,
#  'max_leaf_nodes': 4,
#  'random_state': 2}
